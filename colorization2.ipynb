# %%
from tqdm import tqdm

# %%
from PIL import Image
import numpy as np
import cv2
from cv2 import dnn
import os
import matplotlib.pyplot as plt
from PIL import Image as im 
import PIL  
 
#--------Model file paths--------#
proto_file = "colorization_deploy_v2.prototxt"
model_file = "colorization_release_v2.caffemodel"
hull_pts = "pts_in_hull.npy"

image_path = "Colorized_Mild"
os.mkdir(image_path)

path_mild_dem = fr"Dataset/Mild_Demented/"
for image in tqdm(os.listdir(path_mild_dem)):
    if image[-3:] == 'jpg':
        net = dnn.readNetFromCaffe(proto_file,model_file)
        kernel = np.load(hull_pts)
        
        print(image)
        img = cv2.imread(path_mild_dem + image)
        
        scaled = img.astype("float32") / 255.0
        lab_img = cv2.cvtColor(scaled, cv2.COLOR_BGR2LAB)
        class8 = net.getLayerId("class8_ab")
        conv8 = net.getLayerId("conv8_313_rh")
        pts = kernel.transpose().reshape(2, 313, 1, 1)
        net.getLayer(class8).blobs = [pts.astype("float32")]
        net.getLayer(conv8).blobs = [np.full([1, 313], 2.606, dtype="float32")]
        resized = cv2.resize(lab_img, (224, 224))
        # split the L channel
        L = cv2.split(resized)[0]
        # mean subtraction
        L -= 50
        net.setInput(cv2.dnn.blobFromImage(L))
        ab_channel = net.forward()[0, :, :, :].transpose((1, 2, 0))
        # resize the predicted 'ab' volume to the same dimensions as our
        # input image
        ab_channel = cv2.resize(ab_channel, (img.shape[1], img.shape[0]))
        L = cv2.split(lab_img)[0]
        # Join the L channel with predicted ab channel
        colorized = np.concatenate((L[:, :, np.newaxis], ab_channel), axis=2)
        colorized = cv2.cvtColor(colorized, cv2.COLOR_LAB2BGR)
        colorized = np.clip(colorized, 0, 1)
        colorized = (255 * colorized).astype("uint8")
        img = cv2.resize(img,(640,640))
        colorized = cv2.resize(colorized,(640,640))
                                
        
        #result = cv2.hconcat([img,colorized])
        #per concatenarle (carino per plottarle e far vedere a galasso comm stam fort)
        #plt.imshow(result)
        #plt.title('Colored Image')
        #plt.show()
        
        data = im.fromarray(colorized)
        picture = data.save("Colorized_Mild/col{0}".format(image[:-4]) +".jpg")
# Out:
#   0%|                                                                                          | 0/896 [00:00<?, ?it/s]
# mild_1.jpg
#   0%|                                                                                  | 1/896 [00:00<09:39,  1.55it/s]
# mild_10.jpg
#   0%|▏                                                                                 | 2/896 [00:01<10:02,  1.48it/s]
# mild_100.jpg
#   0%|▎                                                                                 | 3/896 [00:01<09:42,  1.53it/s]
# mild_101.jpg
#   0%|▎                                                                                 | 4/896 [00:02<09:30,  1.56it/s]
# mild_102.jpg
#   1%|▍                                                                                 | 5/896 [00:03<09:23,  1.58it/s]
# mild_103.jpg
#   1%|▌                                                                                 | 6/896 [00:03<09:35,  1.55it/s]
# mild_104.jpg
# ...

# %%
image_path = "Colorized_Moderate"
os.mkdir(image_path)

path_moderate_mild_dem = fr"Dataset/Moderate_Demented/"
for imagemod in tqdm(os.listdir(path_moderate_mild_dem)):
    if imagemod[-3:] == 'jpg':
        net = dnn.readNetFromCaffe(proto_file,model_file)
        kernel = np.load(hull_pts)
        
        print(imagemod)
        img = cv2.imread(path_moderate_mild_dem + imagemod)
        
        scaled = img.astype("float32") / 255.0
        lab_img = cv2.cvtColor(scaled, cv2.COLOR_BGR2LAB)
        class8 = net.getLayerId("class8_ab")
        conv8 = net.getLayerId("conv8_313_rh")
        pts = kernel.transpose().reshape(2, 313, 1, 1)
        net.getLayer(class8).blobs = [pts.astype("float32")]
        net.getLayer(conv8).blobs = [np.full([1, 313], 2.606, dtype="float32")]
        resized = cv2.resize(lab_img, (224, 224))
        # split the L channel
        L = cv2.split(resized)[0]
        # mean subtraction
        L -= 50
        net.setInput(cv2.dnn.blobFromImage(L))
        ab_channel = net.forward()[0, :, :, :].transpose((1, 2, 0))
        # resize the predicted 'ab' volume to the same dimensions as our
        # input image
        ab_channel = cv2.resize(ab_channel, (img.shape[1], img.shape[0]))
        L = cv2.split(lab_img)[0]
        # Join the L channel with predicted ab channel
        colorized = np.concatenate((L[:, :, np.newaxis], ab_channel), axis=2)
        colorized = cv2.cvtColor(colorized, cv2.COLOR_LAB2BGR)
        colorized = np.clip(colorized, 0, 1)
        colorized = (255 * colorized).astype("uint8")
        img = cv2.resize(img,(640,640))
        colorized = cv2.resize(colorized,(640,640))
                                
        
        #result = cv2.hconcat([img,colorized])
        #per concatenarle (carino per plottarle e far vedere a galasso comm stam fort)
        #plt.imshow(result)
        #plt.title('Colored Image')
        #plt.show()
        
        data = im.fromarray(colorized)
        picture = data.save("Colorized_Moderate/col{0}".format(imagemod[:-4]) +".jpg")
# Out:
#   0%|                                                                                           | 0/64 [00:00<?, ?it/s]
# moderate_1.jpg
#   2%|█▎                                                                                 | 1/64 [00:00<00:34,  1.85it/s]
# moderate_10.jpg
#   3%|██▌                                                                                | 2/64 [00:01<00:37,  1.67it/s]
# moderate_11.jpg
#   5%|███▉                                                                               | 3/64 [00:01<00:36,  1.68it/s]
# moderate_12.jpg
#   6%|█████▏                                                                             | 4/64 [00:02<00:34,  1.72it/s]
# moderate_13.jpg
#   8%|██████▍                                                                            | 5/64 [00:03<00:39,  1.51it/s]
# moderate_14.jpg
#   9%|███████▊                                                                           | 6/64 [00:03<00:35,  1.61it/s]
# moderate_15.jpg
# ...

# %%
image_path = "Colorized_Non_Demented"
os.mkdir(image_path)

path_non_dem = fr"Dataset/Non_Demented/"
for image_non in tqdm(os.listdir(path_non_dem)):
    if image_non[-3:] == 'jpg':
        net = dnn.readNetFromCaffe(proto_file,model_file)
        kernel = np.load(hull_pts)
        
        print(image_non)
        img = cv2.imread(path_non_dem + image_non)
        
        scaled = img.astype("float32") / 255.0
        lab_img = cv2.cvtColor(scaled, cv2.COLOR_BGR2LAB)
        class8 = net.getLayerId("class8_ab")
        conv8 = net.getLayerId("conv8_313_rh")
        pts = kernel.transpose().reshape(2, 313, 1, 1)
        net.getLayer(class8).blobs = [pts.astype("float32")]
        net.getLayer(conv8).blobs = [np.full([1, 313], 2.606, dtype="float32")]
        resized = cv2.resize(lab_img, (224, 224))
        # split the L channel
        L = cv2.split(resized)[0]
        # mean subtraction
        L -= 50
        net.setInput(cv2.dnn.blobFromImage(L))
        ab_channel = net.forward()[0, :, :, :].transpose((1, 2, 0))
        # resize the predicted 'ab' volume to the same dimensions as our
        # input image
        ab_channel = cv2.resize(ab_channel, (img.shape[1], img.shape[0]))
        L = cv2.split(lab_img)[0]
        # Join the L channel with predicted ab channel
        colorized = np.concatenate((L[:, :, np.newaxis], ab_channel), axis=2)
        colorized = cv2.cvtColor(colorized, cv2.COLOR_LAB2BGR)
        colorized = np.clip(colorized, 0, 1)
        colorized = (255 * colorized).astype("uint8")
        img = cv2.resize(img,(640,640))
        colorized = cv2.resize(colorized,(640,640))
                                
        
        #result = cv2.hconcat([img,colorized])
        #per concatenarle (carino per plottarle e far vedere a galasso comm stam fort)
        #plt.imshow(result)
        #plt.title('Colored Image')
        #plt.show()
        
        data = im.fromarray(colorized)
        picture = data.save("Colorized_Non_Demented/col{0}".format(image_non[:-4]) +".jpg")
# Out:
#   0%|                                                                                         | 0/3200 [00:00<?, ?it/s]
# non_1.jpg
#   0%|                                                                                 | 1/3200 [00:00<33:29,  1.59it/s]
# non_10.jpg
#   0%|                                                                                 | 2/3200 [00:01<32:20,  1.65it/s]
# non_100.jpg
#   0%|                                                                                 | 3/3200 [00:01<32:45,  1.63it/s]
# non_1000.jpg
#   0%|                                                                                 | 4/3200 [00:02<32:03,  1.66it/s]
# non_1001.jpg
#   0%|▏                                                                                | 5/3200 [00:03<34:28,  1.54it/s]
# non_1002.jpg
#   0%|▏                                                                                | 6/3200 [00:03<34:06,  1.56it/s]
# non_1003.jpg
# ...

# %%
image_path = "Colorized_Very_Mild_Demented"
os.mkdir(image_path)

path_very_mild_dem = fr"Dataset/Very_Mild_Demented/"
for image_vm in tqdm(os.listdir(path_very_mild_dem)):
    if image_vm[-3:] == 'jpg':
        net = dnn.readNetFromCaffe(proto_file,model_file)
        kernel = np.load(hull_pts)
        
        print(image_vm)
        img = cv2.imread(path_very_mild_dem + image_vm)
        
        scaled = img.astype("float32") / 255.0
        lab_img = cv2.cvtColor(scaled, cv2.COLOR_BGR2LAB)
        class8 = net.getLayerId("class8_ab")
        conv8 = net.getLayerId("conv8_313_rh")
        pts = kernel.transpose().reshape(2, 313, 1, 1)
        net.getLayer(class8).blobs = [pts.astype("float32")]
        net.getLayer(conv8).blobs = [np.full([1, 313], 2.606, dtype="float32")]
        resized = cv2.resize(lab_img, (224, 224))
        # split the L channel
        L = cv2.split(resized)[0]
        # mean subtraction
        L -= 50
        net.setInput(cv2.dnn.blobFromImage(L))
        ab_channel = net.forward()[0, :, :, :].transpose((1, 2, 0))
        # resize the predicted 'ab' volume to the same dimensions as our
        # input image
        ab_channel = cv2.resize(ab_channel, (img.shape[1], img.shape[0]))
        L = cv2.split(lab_img)[0]
        # Join the L channel with predicted ab channel
        colorized = np.concatenate((L[:, :, np.newaxis], ab_channel), axis=2)
        colorized = cv2.cvtColor(colorized, cv2.COLOR_LAB2BGR)
        colorized = np.clip(colorized, 0, 1)
        colorized = (255 * colorized).astype("uint8")
        img = cv2.resize(img,(640,640))
        colorized = cv2.resize(colorized,(640,640))
                                
        
        #result = cv2.hconcat([img,colorized])
        #per concatenarle (carino per plottarle e far vedere a galasso comm stam fort)
        #plt.imshow(result)
        #plt.title('Colored Image')
        #plt.show()
        
        data = im.fromarray(colorized)
        picture = data.save("Colorized_Very_Mild_Demented/col{0}".format(image_vm[:-4]) +".jpg")
# Out:
#   0%|                                                                                         | 0/2241 [00:00<?, ?it/s]
# verymild_1.jpg
#   0%|                                                                                 | 2/2241 [00:00<10:33,  3.53it/s]
# verymild_10.jpg
#   0%|                                                                                 | 3/2241 [00:01<14:55,  2.50it/s]
# verymild_100.jpg
#   0%|▏                                                                                | 4/2241 [00:01<18:07,  2.06it/s]
# verymild_1000.jpg
#   0%|▏                                                                                | 5/2241 [00:02<20:19,  1.83it/s]
# verymild_1001.jpg
#   0%|▏                                                                                | 6/2241 [00:03<21:52,  1.70it/s]
# verymild_1002.jpg
#   0%|▎                                                                                | 7/2241 [00:03<21:35,  1.72it/s]
# verymild_1003.jpg
# ...
